# %%
from urllib.request import Request, urlopen
from datetime import datetime
import json
import pandas as pd
import time
from dateutil.relativedelta import relativedelta
import os

# %%
(datetime.now() - relativedelta(years=2)).timestamp()
datetime.now().timestamp()
# this is the date we are going to go back until
# Out:
# 1680906827.093135

# %%
# 6h - 21600
# 1h - 3600
# 5m - 300

def get_prices_at_time(delta, curr_time :float):
    url = 'https://prices.runescape.wiki/api/v1/osrs/'
    # we want the latest data, so lets add that to the url
    url += str(delta)
    url += "?timestamp="
    # url += today.strftime("%f")
    if(delta == '5m'):
        url += str(int(curr_time - (curr_time%300)))
    elif(delta == '1h'):
        url += str(int(curr_time - (curr_time%3600)))
    elif(delta == '6h'):
        url += str(int(curr_time - (curr_time%21600)))
    else:
        ValueError()

    print(url)
    headers = {
        # the wiki blocks all common user-agents in order to prevent spam
        # after talking with some of the API maintainers over discord they asked me to include my discord in the user-agent
        'User-Agent': 'Storing Past Data- @Be#9998',
    }
    req = Request(url, headers=headers)

    with urlopen(req) as response:
        latestData = response.read()
    data = json.loads(latestData)

    data['data']
    return data['data']

# %%
def test(delta, start_time = None):
    times = {}
    if(start_time is None):
        t = time.time()
    else:
        t = start_time
        
    two_yrs_ago = datetime.now() - relativedelta(years=1)
    # two_yrs_ago = datetime.now() - relativedelta(years=1)
    while(t > two_yrs_ago.timestamp()):
        time_df = get_prices_at_time(delta, t)
        # df = pd.DataFrame.from_dict(time_df)
        # df = df.transpose()
        # df_json = df.to_json()
        # print(df_json)
        label = 0
        if(delta == '5m'):
            label = str(int(t - (t%300)))
        elif(delta == '1h'):
            label = str(int(t - (t%3600)))
        elif(delta == '6h'):
            label = str(int(t - (t%21600)*4)) # once a day
        # times[label] = df_json
        times[label] = time_df
        if(delta == '6h'):
            t = t-21600
        elif(delta == '1h'):
            t = t-3600
        elif(delta == '5m'):
            t = t-300
        else:
            ValueError()
        time.sleep(0.1)
    return times

# %%
# historical_time = test('6h', 1617960256)
# try:
#     f = open('Data/Historical.json', 'w')
# except:
#     os.mkdir('Data')
#     f = open('Data/Historical.json', 'w')
# f.write(json.dumps(historical_time, indent=4))
# f.close()

# %%
def test2(delta, id, start_time = None):
    times = {}
    if(start_time is None):
        t = datetime.now().timestamp() - (21600*365)
    else:
        t = start_time
    
    print(t)

    two_yrs_ago = datetime.now() - relativedelta(years=2)
    # two_yrs_ago = datetime.now() - relativedelta(years=1)
    while(t > two_yrs_ago.timestamp()):
        time_df = get_prices_at_time(delta, t)
        # df = pd.DataFrame.from_dict(time_df)
        # df = df.transpose()
        # df_json = df.to_json()
        # print(df_json)
        label = 0
        if(delta == '5m'):
            label = str(int(t - (t%300)))
        elif(delta == '1h'):
            label = str(int(t - (t%3600)))
        elif(delta == '6h'):
            label = str(int(t - (t%21600)))
        # times[label] = df_json
        if(delta == '6h'):
            t = t-(21600*4)
        elif(delta == '1h'):
            t = t-3600
        elif(delta == '5m'):
            t = t-300
        else:
            ValueError()
        try:
            times[label] = time_df[str(id)]
        except:
            print("ERRORRRRasdasdasdasdRRR HERE)")

            continue
        time.sleep(0.1)
    return times

# %%
import NameIDHelper
# id = NameIDHelper.NameToID("Twisted bow")
def get_historical(name, save=True):
    id = NameIDHelper.NameToID(name)
    print(id)
    try:
        # historical_time = test('6h', 1652175674)
        # historical_time = test2('6h', id)
        historical_time = test2('6h', id,datetime.now().timestamp() - (21600*365))

        if(save):
            try:
                f = open('Data/Historical/' + str(id) + '.json', 'w')
            except:
                try:
                    os.mkdir('Data')
                except:
                    os.mkdir('Data/Historical')
                f = open('Data/Historical/' + str(id) + '.json', 'w')
            f.write(json.dumps(historical_time, indent=4))
            f.close()
    except:
        print("To soon to current date to retrieve historical data")
        KeyError()

# %%
get_historical("Twisted bow")
# Out:
# 20997
# 1673022827.30778
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1673006400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672920000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672833600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672747200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672660800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672574400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672488000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672401600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672315200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672228800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672142400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1672056000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671969600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671883200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671796800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671710400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671624000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671537600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671451200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671364800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671278400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671192000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671105600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1671019200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670932800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670846400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670760000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670673600
# ERRORRRRasdasdasdasdRRR HERE)
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670587200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670500800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670414400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670328000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670241600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670155200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1670068800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669982400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669896000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669809600
# ERRORRRRasdasdasdasdRRR HERE)
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669723200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669636800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669550400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669464000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669377600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669291200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669204800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669118400
# ERRORRRRasdasdasdasdRRR HERE)
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1669032000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668945600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668859200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668772800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668686400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668600000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668513600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668427200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668340800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668254400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668168000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1668081600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667995200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667908800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667822400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667736000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667649600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667563200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667476800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667390400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667304000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667217600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667131200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1667044800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666958400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666872000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666785600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666699200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666612800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666526400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666440000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666353600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666267200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666180800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666094400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1666008000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665921600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665835200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665748800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665662400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665576000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665489600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665403200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665316800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665230400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665144000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1665057600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664971200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664884800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664798400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664712000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664625600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664539200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664452800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664366400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664280000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664193600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664107200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1664020800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663934400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663848000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663761600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663675200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663588800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663502400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663416000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663329600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663243200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663156800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1663070400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662984000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662897600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662811200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662724800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662638400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662552000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662465600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662379200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662292800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662206400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662120000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1662033600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661947200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661860800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661774400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661688000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661601600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661515200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661428800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661342400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661256000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661169600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1661083200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660996800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660910400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660824000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660737600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660651200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660564800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660478400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660392000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660305600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660219200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660132800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1660046400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659960000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659873600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659787200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659700800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659614400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659528000
# ERRORRRRasdasdasdasdRRR HERE)
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659441600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659355200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659268800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659182400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659096000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1659009600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658923200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658836800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658750400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658664000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658577600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658491200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658404800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658318400
# ERRORRRRasdasdasdasdRRR HERE)
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658232000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658145600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1658059200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657972800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657886400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657800000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657713600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657627200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657540800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657454400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657368000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657281600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657195200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657108800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1657022400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656936000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656849600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656763200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656676800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656590400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656504000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656417600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656331200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656244800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656158400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1656072000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655985600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655899200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655812800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655726400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655640000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655553600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655467200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655380800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655294400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655208000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655121600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1655035200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654948800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654862400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654776000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654689600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654603200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654516800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654430400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654344000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654257600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654171200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1654084800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653998400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653912000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653825600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653739200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653652800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653566400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653480000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653393600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653307200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653220800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653134400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1653048000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652961600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652875200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652788800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652702400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652616000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652529600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652443200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652356800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652270400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652184000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652097600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1652011200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651924800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651838400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651752000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651665600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651579200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651492800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651406400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651320000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651233600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651147200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1651060800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650974400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650888000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650801600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650715200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650628800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650542400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650456000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650369600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650283200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650196800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650110400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1650024000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1649937600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1649851200
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1649764800
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1649678400
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1649592000
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1649505600
# https://prices.runescape.wiki/api/v1/osrs/6h?timestamp=1649419200
